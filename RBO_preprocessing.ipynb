# %%
import pandas as pd
import numpy as np
import xlrd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## RBO Dataset

# %%
rbo_name = "RBOs.xlsx"

# read sheet 0 of an excel file
data_rbo = pd.read_excel(rbo_name, sheet_name = 0)

# read sheet 1 of an excel file
codebook_rbo = pd.read_excel(rbo_name, sheet_name = 1)

# %%
data_rbo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466 entries, 0 to 465
# Data columns (total 73 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BCCODE           466 non-null    object
#  1   CCODE            466 non-null    object
#  2   RBO              466 non-null    object
#  3   BCODE            466 non-null    object
#  4   RIV_NAME         466 non-null    object
#  5   RBO_NAME         466 non-null    object
#  6   AGREEMENT_NAME   455 non-null    object
#  7   AGREEMENT_DATE   466 non-null    object
#  8   Continent        466 non-null    object
#  9   RIP_NAMES        466 non-null    object
#  10  RIP_NO           466 non-null    int64
#  11  MEMB_NAMES       466 non-null    object
#  12  MEMB_NO          466 non-null    int64
#  13  LATERALITY       466 non-null    object
#  14  INCLUSIVENESS    466 non-null    object
#  15  ISSUES_NAMES     466 non-null    object
#  16  ISSUE_TYPES      466 non-null    object
# ...

# %%
#data_rbo = data_rbo.drop(columns=['BCCODE', 'CCODE'])
data_rbo = data_rbo[[ 'RBO','BCODE','PUB_PART_EX','Continent', 'RBO_NAME',  
                      'AGREEMENT_NAME', 'AGREEMENT_DATE', 
                      'PUB_PART_MEC', 'PUB_PART_TYPE']]

# %%
data_rbo.shape
# Out:
# (466, 9)

# %%
data_rbo
# Out:
#       RBO BCODE PUB_PART_EX Continent  \
# 0    ALGX  VOLT          no    Africa
# 1    ALGX  VOLT          no    Africa
# 2    ALGX  VOLT          no    Africa
# 3    ALGX  NGER          no    Africa
# 4    ALGX  NGER          no    Africa
# ..    ...   ...         ...       ...
# 461  ZAMC  ZAMB         yes    Africa
# 462  ZAMC  ZAMB         yes    Africa
# 463  ZAMC  ZAMB         yes    Africa
# 464  ZRAX  ZAMB         yes    Africa
# 465  ZRAX  ZAMB         yes    Africa
#
#                                               RBO_NAME  \
# 0    Autorité de Développement Integré de la Région...
# 1    Autorité de Développement Integré de la Région...
# 2    Autorité de Développement Integré de la Région...
# 3    Autorité de Développement Integré de la Région...
# 4    Autorité de Développement Integré de la Région...
# ..                                                 ...
# 461             Zambezi Watercouse Commission (ZAMCOM)
# ...

# %%
data_rbo.loc[data_rbo.duplicated(subset=['RBO','BCODE']),:]
# Out:
#       RBO BCODE PUB_PART_EX Continent  \
# 1    ALGX  VOLT          no    Africa
# 2    ALGX  VOLT          no    Africa
# 4    ALGX  NGER          no    Africa
# 5    ALGX  NGER          no    Africa
# 7    ARBC  AMUR           .      Asia
# ..    ...   ...         ...       ...
# 460  ZAMC  ZAMB         yes    Africa
# 461  ZAMC  ZAMB         yes    Africa
# 462  ZAMC  ZAMB         yes    Africa
# 463  ZAMC  ZAMB         yes    Africa
# 465  ZRAX  ZAMB         yes    Africa
#
#                                               RBO_NAME  \
# 1    Autorité de Développement Integré de la Région...
# 2    Autorité de Développement Integré de la Région...
# 4    Autorité de Développement Integré de la Région...
# 5    Autorité de Développement Integré de la Région...
# 7              Amur River Basin Coordination Committee
# ..                                                 ...
# 460             Zambezi Watercouse Commission (ZAMCOM)
# ...

# %%
data_rbo = data_rbo.drop_duplicates()

# %%
data_rbo.shape
# Out:
# (168, 9)

# %%
data_rbo = data_rbo.sort_values(by=['BCODE'])
data_rbo
# Out:
#       RBO BCODE PUB_PART_EX      Continent  \
# 210  IJCX  ALSK         yes  North America
# 393  PSCX  ALSK           .  North America
# 6    ARBC  AMUR           .           Asia
# 359  OCTA  AMZN         yes  Latin America
# 9    ASBP  ARAL           .           Asia
# ..    ...   ...         ...            ...
# 136  IBWC  YAQU         yes  North America
# 230  IJCX  YUKN         yes  North America
# 456  ZAMC  ZAMB         yes         Africa
# 464  ZRAX  ZAMB         yes         Africa
# 25   BCEC  ZAPL           .  Latin America
#
#                                               RBO_NAME  \
# 210                     International Joint Commission
# 393                          Pacific Salmon Commission
# 6              Amur River Basin Coordination Committee
# 359      Organization of the Amazon Cooperation Treaty
# 9                             Aral Sea Basin Programme
# ..                                                 ...
# ...

# %%
data_rbo.duplicated(subset=['RBO','BCODE']).value_counts()
# Out:
# False    163
# True       5
# dtype: int64

# %%
data_rbo.loc[data_rbo.duplicated(subset=['RBO','BCODE'])]
# Out:
#      RBO BCODE PUB_PART_EX Continent  \
# 64  CTCX  ARAL           .      Asia
# 34  CCNR  RHIN         yes    Europe
# 35  CCNR  RHIN         yes    Europe
# 36  CCNR  RHIN         yes    Europe
# 37  CCNR  RHIN         yes    Europe
#
#                                              RBO_NAME  \
# 64  Commission of the Republic of Kazakhstan and t...
# 34  Central Commission for the Navigation of the R...
# 35  Central Commission for the Navigation of the R...
# 36  Central Commission for the Navigation of the R...
# 37  Central Commission for the Navigation of the R...
#
#                                        AGREEMENT_NAME AGREEMENT_DATE  \
# 64  Agreement on Utilization of the Water Faciliti...           2006
# 34            Congress of Vienna/Treaty of Versailles      1816/1922
# 35            Congress of Vienna/Treaty of Versailles      1816/1923
# 36            Congress of Vienna/Treaty of Versailles      1816/1924
# ...

# %%
data_rbo = data_rbo.drop_duplicates(subset=['RBO','BCODE'], keep='first')

# %%
data_rbo.shape
# Out:
# (163, 9)

# %%
data_rbo
# Out:
#       RBO BCODE PUB_PART_EX      Continent  \
# 210  IJCX  ALSK         yes  North America
# 393  PSCX  ALSK           .  North America
# 6    ARBC  AMUR           .           Asia
# 359  OCTA  AMZN         yes  Latin America
# 9    ASBP  ARAL           .           Asia
# ..    ...   ...         ...            ...
# 136  IBWC  YAQU         yes  North America
# 230  IJCX  YUKN         yes  North America
# 456  ZAMC  ZAMB         yes         Africa
# 464  ZRAX  ZAMB         yes         Africa
# 25   BCEC  ZAPL           .  Latin America
#
#                                               RBO_NAME  \
# 210                     International Joint Commission
# 393                          Pacific Salmon Commission
# 6              Amur River Basin Coordination Committee
# 359      Organization of the Amazon Cooperation Treaty
# 9                             Aral Sea Basin Programme
# ..                                                 ...
# ...

# %%
data_rbo.to_csv("RBO_dots.csv")

# %%
data_rbo['PUB_PART_EX'].value_counts()
# Out:
# .      84
# yes    58
# no     21
# Name: PUB_PART_EX, dtype: int64

# %%
data_rbo_no_dots = data_rbo[data_rbo['PUB_PART_EX'] != '.']

# %%
data_rbo_no_dots
# Out:
#       RBO BCODE PUB_PART_EX      Continent  \
# 210  IJCX  ALSK         yes  North America
# 359  OCTA  AMZN         yes  Latin America
# 194  ICWC  ARAL         yes           Asia
# 128  IBWC  CLDO         yes  North America
# 212  IJCX  CLKT         yes  North America
# ..    ...   ...         ...            ...
# 228  IJCX  WHIT         yes  North America
# 136  IBWC  YAQU         yes  North America
# 230  IJCX  YUKN         yes  North America
# 456  ZAMC  ZAMB         yes         Africa
# 464  ZRAX  ZAMB         yes         Africa
#
#                                               RBO_NAME  \
# 210                     International Joint Commission
# 359      Organization of the Amazon Cooperation Treaty
# 194  Interstate Commission for Water Coordination i...
# 128        International Water and Boundary Commission
# 212                     International Joint Commission
# ..                                                 ...
# ...

# %%
data_rbo_no_dots.to_csv("RBO_no_dots.csv")

# %%
data_rbo_no_dots.to_excel("RBO_no_dots.xlsx")
data_rbo.to_excel("RBO_dots.xlsx")
